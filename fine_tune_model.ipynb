# %% [markdown]
# <a href="https://colab.research.google.com/github/Navaneeth-Punna/next-gen-ids/blob/main/fine_tune_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install all required libraries in one go
# !pip install -q torch transformers datasets peft bitsandbytes scikit-learn

# --- 1. Data Preparation ---
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import load_dataset, Dataset
from transformers import AutoTokenizer, DataCollatorForLanguageModeling
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, Trainer
from accelerate import Accelerator
import os
import torch
from peft import LoraConfig, get_peft_model

print("--- Step 1: Downloading and Preprocessing Data ---")

# Load the 'emotion' dataset directly from Hugging Face
raw_dataset = load_dataset("emotion")
df = pd.concat([raw_dataset['train'].to_pandas(), raw_dataset['validation'].to_pandas()])
print("Dataset downloaded and loaded successfully.")

# Convert to instruction-based format
def create_instruction_data(df):
    data = []
    for _, row in df.iterrows():
        log_content = row['text']
        label = row['label']
        prompt_template = (
            "### Instruction:\nAnalyze the following log and determine its sentiment. "
            "Classify it as one of the following: sadness, joy, love, anger, fear, or surprise. "
            "Explain why and provide an example of a similar log.\n\n"
            "### Log Entry:\n{log_content}\n\n"
            "### Output:"
        )
        label_map = {0: "sadness", 1: "joy", 2: "love", 3: "anger", 4: "fear", 5: "surprise"}
        output = f"Label: {label_map[label]}\nExplanation: The message expresses {label_map[label]}."
        data.append({"text": f"{prompt_template.format(log_content=log_content)}{output}"})
    return Dataset.from_pandas(pd.DataFrame(data))

instruction_dataset = create_instruction_data(df)
print("Instruction dataset created.")

# Split the dataset before tokenization
train_dataset, eval_dataset = instruction_dataset.train_test_split(test_size=0.1).values()
print("Data split into training and evaluation sets.")


# --- 2. LLM Fine-tuning ---


print("--- Step 2: Fine-tuning the LLM ---")

# Hugging Face login
# Please generate a new Hugging Face token with access to public gated repositories and paste it when prompted below.
# Go to: https://huggingface.co/settings/tokens to create a new token.
# !huggingface-cli login
print("Hugging Face login command executed. Please check the output above for login status and ensure you used a token with appropriate permissions.")


# 4-bit Quantization Configuration
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

# Load Model and Tokenizer
model_id = "EleutherAI/Pythia-160m" # Corrected model_id for Pythia
tokenizer = AutoTokenizer.from_pretrained(model_id, pad_token="<|endoftext|>")
# Set pad_token_id explicitly for clarity
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    device_map="auto"
)

# Disable gradient checkpointing for debugging
# model.gradient_checkpointing_enable()


# Tokenize the datasets
def tokenize_function(examples):
    tokenized_output = tokenizer(examples['text'], padding="max_length", truncation=True, max_length=256) # Reduced max_length
    return tokenized_output

train_dataset = train_dataset.map(tokenize_function, batched=True)
eval_dataset = eval_dataset.map(tokenize_function, batched=True)

# Remove the original 'text' column after tokenization
train_dataset = train_dataset.remove_columns(["text"])
eval_dataset = eval_dataset.remove_columns(["text"])

# Set dataset format to torch
train_dataset.set_format("torch")
eval_dataset.set_format("torch")


print("Data preprocessed and ready for fine-tuning.")

# LoRA Configuration
lora_config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["query_key_value", "dense"], # Adjusted target modules for Pythia
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
model = get_peft_model(model, lora_config)
print("Model loaded and prepared for fine-tuning.")

# Print requires_grad status of model parameters
print("Requires grad status of model parameters:")
for name, param in model.named_parameters():
    print(f"{name}: {param.requires_grad}")


# Data Collator
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)


# Training Arguments
training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1, # Reduced eval batch size
    gradient_accumulation_steps=4,
    learning_rate=2e-4,
    num_train_epochs=1,
    logging_steps=10,
    save_strategy="epoch",
    fp16=True,
    report_to="none",
)

# Trainer
trainer = Trainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    args=training_args,
    data_collator=data_collator,
    tokenizer=tokenizer,
)

print("Starting fine-tuning...")
trainer.train()
print("Fine-tuning complete. The trained model is ready for inference.")

# --- Evaluating the fine-tuned model ---
print("--- Evaluating the fine-tuned model ---")
evaluation_results = trainer.evaluate()
print(evaluation_results)
# Out:
# --- Step 1: Downloading and Preprocessing Data ---
# Dataset downloaded and loaded successfully.
# Instruction dataset created.
# Data split into training and evaluation sets.
# --- Step 2: Fine-tuning the LLM ---
# ⚠️  Warning: 'huggingface-cli login' is deprecated. Use 'hf auth login' instead.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: fineGrained).
# The token `new token` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `new token`
# Hugging Face login command executed. Please check the output above for login status and ensure you used a token with appropriate permissions.
# Map:   0%|          | 0/16200 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1800 [00:00<?, ? examples/s]
# /tmp/ipython-input-2495003634.py:140: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 0}.
# Data preprocessed and ready for fine-tuning.
# Model loaded and prepared for fine-tuning.
# Requires grad status of model parameters:
# base_model.model.gpt_neox.embed_in.weight: False
# base_model.model.gpt_neox.layers.0.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.0.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.0.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.0.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.0.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.0.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.0.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.0.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.0.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.0.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.0.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.0.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.0.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.0.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.0.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.0.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.1.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.1.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.1.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.1.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.1.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.1.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.1.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.1.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.1.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.1.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.1.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.1.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.1.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.1.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.1.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.1.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.2.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.2.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.2.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.2.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.2.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.2.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.2.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.2.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.2.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.2.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.2.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.2.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.2.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.2.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.2.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.2.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.3.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.3.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.3.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.3.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.3.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.3.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.3.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.3.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.3.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.3.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.3.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.3.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.3.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.3.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.3.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.3.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.4.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.4.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.4.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.4.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.4.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.4.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.4.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.4.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.4.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.4.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.4.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.4.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.4.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.4.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.4.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.4.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.5.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.5.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.5.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.5.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.5.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.5.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.5.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.5.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.5.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.5.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.5.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.5.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.5.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.5.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.5.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.5.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.6.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.6.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.6.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.6.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.6.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.6.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.6.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.6.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.6.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.6.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.6.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.6.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.6.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.6.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.6.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.6.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.7.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.7.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.7.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.7.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.7.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.7.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.7.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.7.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.7.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.7.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.7.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.7.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.7.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.7.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.7.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.7.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.8.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.8.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.8.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.8.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.8.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.8.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.8.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.8.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.8.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.8.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.8.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.8.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.8.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.8.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.8.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.8.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.9.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.9.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.9.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.9.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.9.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.9.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.9.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.9.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.9.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.9.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.9.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.9.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.9.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.9.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.9.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.9.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.10.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.10.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.10.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.10.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.10.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.10.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.10.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.10.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.10.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.10.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.10.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.10.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.10.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.10.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.10.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.10.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.layers.11.input_layernorm.weight: False
# base_model.model.gpt_neox.layers.11.input_layernorm.bias: False
# base_model.model.gpt_neox.layers.11.post_attention_layernorm.weight: False
# base_model.model.gpt_neox.layers.11.post_attention_layernorm.bias: False
# base_model.model.gpt_neox.layers.11.attention.query_key_value.base_layer.weight: False
# base_model.model.gpt_neox.layers.11.attention.query_key_value.base_layer.bias: False
# base_model.model.gpt_neox.layers.11.attention.query_key_value.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.11.attention.query_key_value.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.11.attention.dense.base_layer.weight: False
# base_model.model.gpt_neox.layers.11.attention.dense.base_layer.bias: False
# base_model.model.gpt_neox.layers.11.attention.dense.lora_A.default.weight: True
# base_model.model.gpt_neox.layers.11.attention.dense.lora_B.default.weight: True
# base_model.model.gpt_neox.layers.11.mlp.dense_h_to_4h.weight: False
# base_model.model.gpt_neox.layers.11.mlp.dense_h_to_4h.bias: False
# base_model.model.gpt_neox.layers.11.mlp.dense_4h_to_h.weight: False
# base_model.model.gpt_neox.layers.11.mlp.dense_4h_to_h.bias: False
# base_model.model.gpt_neox.final_layer_norm.weight: False
# base_model.model.gpt_neox.final_layer_norm.bias: False
# base_model.model.embed_out.weight: False
# Starting fine-tuning...
#     <div>
#
#       <progress value='4050' max='4050' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4050/4050 21:17, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>3.220100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.831800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.281200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.926000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.097900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.927500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.033100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.795800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.974700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.029900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.967000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.005200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.834200</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.939600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.092900</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.945500</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.885600</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.967800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.048200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.943200</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.885200</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.026100</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.086000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.972800</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.842500</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.017900</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.871000</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>1.100700</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.946500</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.824700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.937000</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.874100</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.914400</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.910200</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.905700</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.008700</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.787800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.888500</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.922800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.926500</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.027000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.878000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.878100</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.862500</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.842900</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.868500</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.858900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.137300</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.942800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.145600</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.869300</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.854300</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.857000</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.856300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.798900</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.907800</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.928600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.896300</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.004500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.978200</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.909600</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.987500</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.890800</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.965500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.895200</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.807600</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.890600</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.866600</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.886600</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>1.000400</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.886000</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.961900</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.970600</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.927800</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.929900</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.905000</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.977900</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>1.002900</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.789900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.905800</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.901600</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.865800</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.881800</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.952500</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.857700</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.899100</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.853800</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.775700</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.907400</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.872500</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.863900</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.832000</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.925100</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.897400</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.971900</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.989500</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.846400</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.879300</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.970500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.839200</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>1.025600</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.750000</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.814300</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.878000</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.833900</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.946800</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.968600</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.939400</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.899600</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.778300</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.879900</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.863500</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.866300</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.875000</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.941300</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.914100</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.929100</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.945400</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.907100</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.786500</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.905000</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.851800</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.992500</td>
#     </tr>
#     <tr>
#       <td>124
# Fine-tuning complete. The trained model is ready for inference.
# --- Evaluating the fine-tuned model ---
#     <div>
#
#       <progress value='1800' max='1800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1800/1800 01:08]
#     </div>
# {'eval_loss': 0.857168972492218, 'eval_runtime': 69.0288, 'eval_samples_per_second': 26.076, 'eval_steps_per_second': 26.076, 'epoch': 1.0}
